# %%
from scipy.stats import chi2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import urllib

# Read a .txt or .csv file containing SNPs and P values to be plotted
# Function checks delimiters automatically
# Parameter: filename - .txt or .csv file containing information needed
# Return: pandas dataframe of the file
def __read_file(filename):
    fh = open(filename, 'r')
    line = fh.readline()
    tmp = line.strip().split(',')

    # Create an empty dataframe, read data into df later
    df = pd.DataFrame()
    # Check delimiter type, "," or " "
    if len(tmp) == 1:
        df = pd.read_csv(filename, delim_whitespace=True)
    else:
        df = pd.read_csv(filename)
    
    return(df)

# Return -log10 transformed observed and expected p vlaues of a dataset(dataframe)
def __log_obsv_and_expt(df, column_title):
    Pobsv = df.loc[:, column_title]  # Observed p values
    Pobsv = np.sort(Pobsv.dropna().values)
    Pexpt = np.arange(1, len(Pobsv) + 1, 1) / (len(Pobsv) + 1)  # Expected
    logPobsv = -np.log10(Pobsv)
    logPexpt = -np.log10(Pexpt)
    
    return(Pobsv, logPobsv, logPexpt)


# Calculate and return lambda (inflation)
def __get_inflation__(observed):
    obsv_median = np.median(observed)
    Chi = chi2.ppf(1.0 - obsv_median, 1)
    lmbd = Chi / chi2.ppf(0.5, 1)
    return lmbd


# The tricky part for me is to query haploreg database thorugh their website.
# Inspecct the element of the website to find out names of each variable
# Recommand using Chrome, go to developer mode, refresh the website under Network tab
# This function is intended to query one SNP at a time
# Return: a set of rsIDs of accociated SNPs (and the queried SNP)

# Parameters needed to send to haploreg website, and some explaination
# input_snps (query): input SNPs in a string, each SNP is separated by ','
#        SNP number per query is set to be 1000, otherwise it takes too long and haploreg may refuse to do it.
#        15000 SNPs did not work for test run.
# gwas_id: the dropdown list to choose GWAS study, when no file or query SNP(s) is provided
# r2_threshold (ldThresh): r^2 threshold, default is 0.2 in this code
# ldPop: 1000G Phase 1 population for LD calculation
# epi: Source for epigenomes
# cons: Mammalian conservation algorithm. 'siphy'=SiPhy-omega, 'gerp'=GERP, or 'both'
# genetypes: Show position relative to
# output: set output result type to 'text' for python code to process
def single_query_haploreg(input_snp,
                   r2_threshold=0.2,
                   ldPop='EUR',
                   epi='vanilla',
                   cons='siphy',
                   genetypes='gencode'):

    params_library = {'query':input_snp,
                      'gwas_id':0,
                      'ldThresh': r2_threshold,
                      'ldPop': ldPop,
                      'epi': epi,
                      'cons': cons,
                      'genetypes': genetypes,
                      'output':'text'}
    
    # parameters passed to the website, needs to be parsed and in binary
    params = urllib.parse.urlencode(params_library).encode("utf-8")
    # url of HaploReg4.1
    url = 'https://pubs.broadinstitute.org/mammals/haploreg/haploreg.php'
    # Query with parameters
    query = urllib.request.urlopen(url, params)
    content = query.read().decode("utf-8")
    # Find accociated SNPs in the content returned from HaploReg
    matches = re.findall('rs[0-9]+', content)

    # Return unique ones of the query
    return(set(matches))
#     return content


# Queried SNPs are based on the file provided
# Parameter:
# - 
# -
# Return: Save novel SNPs as .csv file fot plotting and reference
def __novel_SNPs(filename, r2_threshold, SNPs_column_title, novel_filename='novel_SNPs.csv'):
    original_df = __read_file(filename) # Dataframe read from the file
    all_SNPs = original_df.loc[:, SNPs_column_title].values # Get all SNPs in the file to be queried
    associated_SNPs = np.array([]) # A numpy array to store queried results
    
    # Count is to show numbers of SNPs processed so far, to keep the console updating
    count = 0
    for snp in all_SNPs:
        associated_SNPs = np.append(associated_SNPs, single_query_haploreg(input_snp=snp, r2_threshold=r2_threshold))
        
        count = count+1
        # Print every 10 SNPs
        if count%10 == 0:
            print('Number of SNPs processed: ' + str(count))
        
    
    # Remove duplicates of queried results
    associated_SNPs = np.unique(associated_SNPs)
    
    # Join the original dataframe and queried results, output novel SNPs
    original_df.set_index(SNPs_column_title, inplace=True)
    associated_df = pd.DataFrame([], index=associated_SNPs)
    remove_df = original_df.join(associated_df, how='inner')
    novel_df = original_df.drop(remove_df.index.values)
    
    novel_df.to_csv(novel_filename)

# Returns: (fig, ax, lambda)
# fig and ax for more custermizations
def qqplot(filename,
           output='output.png',
           column_title = 'P',
           title='Q-Q plot',
           xlabel='Expected –log10 P-values',
           ylabel='Observed –log10 P-values',
           dpi=300,
           plot_novel = False,
           novel_filename = 'novel_SNPs.csv',
           SNPs_column_title = 'SNP',
           r2_threshold=0.2):
    
    df = __read_file(filename)
    
#     Pobsv = df.loc[:, column_title]  # Observed p values
#     Pobsv = np.sort(Pobsv.dropna().values)
#     Pexpt = np.arange(1, len(Pobsv) + 1, 1) / (len(Pobsv) + 1)  # Expected
#     logPobsv = -np.log10(Pobsv)
#     logPexpt = -np.log10(Pexpt)

    Pobsv, logPobsv, logPexpt = __log_obsv_and_expt(df, column_title)

    # Calculate lambda
    infl = __get_inflation__(Pobsv)

    fig, ax = plt.subplots(dpi=dpi)
    ax.plot(logPexpt, logPobsv, linestyle='', marker='o', markersize=3, markeredgewidth=0.5,
            fillstyle='none', color='k', alpha=0.8)
    ax.plot(logPexpt, logPexpt, color='r', linewidth=0.4)

    # Label x and y axis
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    annotation = "λ = " + str("{0:.4f}".format(infl))
    ax.annotate(annotation, xy=(0.7, 0.2), xycoords='axes fraction')
    
    if plot_novel == True:
        # Plot novel SNPs, then same steps as before
        __novel_SNPs(filename, r2_threshold, SNPs_column_title, novel_filename)
        novel_SNPs_df = __read_file(novel_filename)
        
#         Pobsv_novel = novel_SNPs_df.loc[:, column_title]  # Observed p values
#         Pobsv_novel = np.sort(Pobsv_novel.dropna().values)
#         Pexpt_novel = np.arange(1, len(Pobsv_novel) + 1, 1) / (len(Pobsv_novel) + 1)  # Expected
#         logPobsv_novel = -np.log10(Pobsv_novel)
#         logPexpt_novel = -np.log10(Pexpt_novel)
        Pobsv_novel, logPobsv_novel, logPexpt_novel = __log_obsv_and_expt(novel_SNPs_df, column_title)

        ax.plot(logPexpt_novel, logPobsv_novel, linestyle='', marker='o', markersize=3, markeredgewidth=0.5,
                fillstyle='none', color='g', alpha=0.8)
    
    fig.savefig(output)
    
    return (fig, ax, infl)  # Return for more custermizations

# %%
# Takes a df and scan for novel SNPs
# Better to process about 100 SNPs at a time, so the process will not take too long.
# column_title is the titile of the column that contains rsIDs
# Output the reuslt into a .csv file
def __associated_SNPs(file_df, column_title='SNP', r2_threshold=0.2, output='associated_SNPs.txt'):
    all_SNPs = file_df.loc[:,column_title].values # Get all SNPs in the file to be queried
    associated_SNPs = set() # A numpy array to store queried results

    for snp in all_SNPs:
        associated_SNPs = np.append(associated_SNPs, single_query_haploreg(input_snp=snp, r2_threshold=r2_threshold))
    
    # Remove duplicates of queried results
    associated_SNPs = np.unique(associated_SNPs)
    np.savetxt(output, associated_SNPs, fmt='%s')

# %%
# This can be single or multiple SNP queris (each rsID is separated by ',')
def query_haploreg(input_snp,
                   r2_threshold=0.2,
                   ldPop='EUR',
                   epi='vanilla',
                   cons='siphy',
                   genetypes='gencode'):

    params_library = {'query':input_snp,
                      'gwas_id':0,
                      'ldThresh': r2_threshold,
                      'ldPop': ldPop,
                      'epi': epi,
                      'cons': cons,
                      'genetypes': genetypes,
                      'output':'text'}
    
    # parameters passed to the website, needs to be parsed and in binary
    params = urllib.parse.urlencode(params_library).encode("utf-8")
    # url of HaploReg4.1
    url = 'https://pubs.broadinstitute.org/mammals/haploreg/haploreg.php'
    # Query with parameters
    query = urllib.request.urlopen(url, params)
    content = query.read().decode("utf-8")
    # Find accociated SNPs in the content returned from HaploReg
    matches = re.findall('rs[0-9]+', content)

    # Return unique ones of the query
    return(list(set(matches)))

# This function returns known SNPs (and associated SNPs) based on user input file
# Parameters:
#  - filename: a file contains known SNPs, provided by user
#  - r2_threshold: LD threshold, defualt is 0.2
#  - SNPs_column_title: Column title of SNPs in that file
# Return: a list of associated SNPs pulled from HaploReg and known SNPs provided by user
def __known_SNPs(filename, r2_threshold=0.2, SNPs_column_title='SNP'):
    known_SNPs_df = __read_file(filename) # Dataframe of known SNPs
    # Get all SNPs to be queried, join them by ',' and query together
    known_SNPs = ','.join(known_SNPs_df.loc[:, SNPs_column_title].values)
    # A numpy array to store queried results
    associated_and_known_SNPs = query_haploreg(input_snp=known_SNPs, r2_threshold=r2_threshold)
    
#     if len(known_SNPs_df)>100:


    # Remove duplicates of queried results and return
    return(set(associated_and_known_SNPs))

# This function removes known SNPs and save novel SNPs in a .csv file
# Parameters:
#  - original_df: a dataframe containing raw data of SNPs and p values
#  - known_SNPs: a list of SNPs found in other GWAS, that are associated with traits of interest
#  - SNPs_column_title: Column title of SNPs in that file
# Return: a datafram of novel SNPs and p values
def __remove_known_SNPs(original_df, known_SNPs, SNPs_column_title='SNP', novel_filename='novel_SNPs'):
    # Join the original dataframe and konw SNPs, output novel SNPs to be plotted
    original_df.set_index(SNPs_column_title, inplace=True)
    known_SNPs_df = pd.DataFrame([], index=known_SNPs)
    to_be_removed_SNPs_df = original_df.join(known_SNPs_df, how='inner')
    novel_df = original_df.drop(to_be_removed_SNPs_df.index.values)
    
    novel_df.to_csv(novel_filename)
    return(novel_df)

# %%
filename = 'Data/DLD_GWAS_10.csv'
a = __known_SNPs(filename)

# %%
original_df = __read_file('Data/ADD_only_DLD_GWAS.txt')
new_df = __remove_known_SNPs(original_df, a)

# %%
import pandas as pd
gwas_filename_01 = "/data100t1/share/DIAMANTE/mrmega_hdl_final_0619_rsids_locuszoom.result"
gwas_filename_02 = "/data100t1/share/DIAMANTE/mrmega_hdl_final_0619_rsids.result"

gwas_df = pd.read_csv(gwas_filename_02, sep='\t')

# fh = open(gwas_filename_02, 'r')
# count=0
# for line in fh:
#     print(line.strip().split('\t'))
#     count=count+1
#     if count>10: break

# %%
gwas_df.head()
# Out:
#     MarkerName  Chromosome   Position EA NEA       EAF  Nsample  Ncohort  \
# 0  rs147324274          10  100000012  G   A  0.996606    26037        4
# 1  rs144804129          10  100000122  T   A  0.997312    27449        6
# 2    rs6602381          10   10000018  A   G  0.541823    38176       19
# 3  rs189891329          10   10000033  G   A  0.994151    26037        4
# 4  rs112832083          10  100000588  T   C  0.992032    28518        7
#
#                Effects    beta_0  ...  ndf_association  P-value_association  \
# 0  -?????????+??????++ -1.252750  ...              2.0             0.317464
# 1  -+?????+??+??????+-  0.086105  ...              2.0             0.765692
# 2  +++--+-++-+-+--++++  0.029652  ...              2.0             0.295628
# 3  -?????????+??????+- -1.370290  ...              2.0             0.475657
# 4  +??-?+?+??+??????+- -0.237271  ...              2.0             0.093044
#
#    chisq_ancestry_het  ndf_ancestry_het  P-value_ancestry_het  \
# 0            0.677718               1.0              0.410374
# 1            0.000672               1.0              0.979314
# 2            0.875949               1.0              0.349314
# 3            1.028940               1.0              0.310409
# 4            1.776260               1.0              0.182610
#
#    chisq_residual_het  ndf_residual_het  P-value_residual_het      lnBF  \
# 0            0.223172               2.0              0.894415 -0.238903
# 1            3.196730               4.0              0.525459 -1.524780
# 2           12.777500              17.0              0.750949 -1.725790
# 3            7.119850               2.0              0.028441 -0.643236
# 4            2.751990               5.0              0.738157  0.428771
#
#    Comments
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 24 columns]

# %%
len(gwas_df)
# Out:
# 33512268

# %%
len(gwas_df)
# Out:
# 33783872

# %%
qqplot(filename=gwas_filename_01,output='20190930_mrmega_hdl.png',
       column_title = 'P-value_association',title='mrmega_hdl')
# Out:
# (<Figure size 1800x1200 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fc6383c5cf8>,
#  1.0720526881638353)

# %%
novel_01 = '/data100t1/share/DIAMANTE/GWAS_catalog_results_HDL.txt'
novel_df = pd.read_csv(novel_01, sep='\t')

# %%
novel_df.head()
# Out:
#   DATE ADDED TO CATALOG  PUBMEDID  FIRST AUTHOR     DATE        JOURNAL  \
# 0               6/21/17  28270201        Nagy R   3/7/17     Genome Med
# 1               2/14/19  29507422   Hoffmann TJ   3/5/18      Nat Genet
# 2               2/14/19  29507422   Hoffmann TJ   3/5/18      Nat Genet
# 3               5/12/14  24097068     Willer CJ  10/6/13      Nat Genet
# 4               6/26/17  28334899  Spracklen CN  2/21/17  Hum Mol Genet
#
#                                    LINK  \
# 0  www.ncbi.nlm.nih.gov/pubmed/28270201
# 1  www.ncbi.nlm.nih.gov/pubmed/29507422
# 2  www.ncbi.nlm.nih.gov/pubmed/29507422
# 3  www.ncbi.nlm.nih.gov/pubmed/24097068
# 4  www.ncbi.nlm.nih.gov/pubmed/28334899
#
#                                                STUDY  \
# 0  Exploration of haplotype research consortium i...
# 1  A large electronic-health-record-based genome-...
# 2  A large electronic-health-record-based genome-...
# 3  Discovery and refinement of loci associated wi...
# 4  Association analyses of East Asian individuals...
#
#                                  DISEASE/TRAIT  \
# 0                              HDL cholesterol
# 1  High density lipoprotein cholesterol levels
# 2  High density lipoprotein cholesterol levels
# 3                              HDL cholesterol
# 4                       HDL cholesterol levels
#
#                                  INITIAL SAMPLE SIZE  \
# 0  19,223 British ancestry individuals from 6863 ...
# 1  76,627 European ancestry individuals, 7,795 Hi...
# 2  76,627 European ancestry individuals, 7,795 Hi...
# 3               94,595 European ancestry individuals
# 4  34,930 East Asian ancestry individuals, 187,16...
#
#                 REPLICATION SAMPLE SIZE  ... PVALUE_MLOG  \
# 0                                   NaN  ...    7.522879
# 1                                   NaN  ...   13.698970
# 2                                   NaN  ...   13.698970
# 3  93,982 European ancestry individuals  ...   15.000000
# 4    8,741 Chinese ancestry individuals  ...   15.045757
#
#            P-VALUE (TEXT) OR or BETA  \
# 0                     NaN   0.867736
# 1                    (EA)   0.113000
# 2                     NaN   0.114000
# 3                     NaN   0.051000
# 4  (Trans-ethnic initial)   0.050600
#
#                                   95% CI (TEXT)  \
# 0                    [0.56-1.18] mg/dl increase
# 1                                 unit increase
# 2                                 unit increase
# 3                            [NR] unit decrease
# 4  [0.038-0.063] unit decrease (EA Beta values)
#
#                    PLATFORM [SNPS PASSING QC] CNV  \
# 0               Illumina [24111857] (imputed)   N
# 1     Affymetrix [at least 7091467] (imputed)   N
# 2     Affymetrix [at least 7091467] (imputed)   N
# 3                           NR [NR] (imputed)   N
# 4  Affymetrix, Illumina [~ 1900000] (imputed)   N
#
#                                        MAPPED_TRAIT  \
# 0  high density lipoprotein cholesterol measurement
# 1  high density lipoprotein cholesterol measurement
# 2  high density lipoprotein cholesterol measurement
# 3  high density lipoprotein cholesterol measurement
# 4  high density lipoprotein cholesterol measurement
#
#                        MAPPED_TRAIT_URI  STUDY ACCESSION  \
# 0  http://www.ebi.ac.uk/efo/EFO_0004612       GCST004207
# 1  http://www.ebi.ac.uk/efo/EFO_0004612       GCST007140
# 2  http://www.ebi.ac.uk/efo/EFO_0004612       GCST007140
# 3  http://www.ebi.ac.uk/efo/EFO_0004612       GCST002223
# 4  http://www.ebi.ac.uk/efo/EFO_0004612       GCST004232
#
#           GENOTYPING TECHNOLOGY
# 0  Genome-wide genotyping array
# 1  Genome-wide genotyping array
# 2  Genome-wide genotyping array
# 3  Genome-wide genotyping array
# 4  Genome-wide genotyping array
#
# [5 rows x 38 columns]

# %%
len(novel_df.T)
# Out:
# 38

# %%
novel_df.T
# Out:
#                                                                          0     \
# DATE ADDED TO CATALOG                                                 6/21/17
# PUBMEDID                                                             28270201
# FIRST AUTHOR                                                           Nagy R
# DATE                                                                   3/7/17
# JOURNAL                                                            Genome Med
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/28270201
# STUDY                       Exploration of haplotype research consortium i...
# DISEASE/TRAIT                                                 HDL cholesterol
# INITIAL SAMPLE SIZE         19,223 British ancestry individuals from 6863 ...
# REPLICATION SAMPLE SIZE                                                   NaN
# REGION                                                                1p36.23
# CHR_ID                                                                      1
#  CHR_POS                                                           8,173,210
# REPORTED GENE(S)                                                   intergenic
# MAPPED_GENE                                           AL034417.2 - AL358876.1
# UPSTREAM_GENE_ID                                              ENSG00000238290
# DOWNSTREAM_GENE_ID                                            ENSG00000229305
# SNP_GENE_IDS                                                              NaN
# UPSTREAM_GENE_DISTANCE                                                  50508
# DOWNSTREAM_GENE_DISTANCE                                                16614
# STRONGEST SNP-RISK ALLELE                                       rs149963466-A
# SNPS                                                              rs149963466
# MERGED                                                                      0
# SNP_ID_CURRENT                                                    1.49963e+08
# CONTEXT                                                    intergenic_variant
# INTERGENIC                                                                  1
# RISK ALLELE FREQUENCY                                                  0.0016
# P-VALUE                                                                 3e-08
# PVALUE_MLOG                                                           7.52288
# P-VALUE (TEXT)                                                            NaN
# OR or BETA                                                           0.867736
# 95% CI (TEXT)                                      [0.56-1.18] mg/dl increase
# PLATFORM [SNPS PASSING QC]                      Illumina [24111857] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST004207
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          1     \
# DATE ADDED TO CATALOG                                                 2/14/19
# PUBMEDID                                                             29507422
# FIRST AUTHOR                                                      Hoffmann TJ
# DATE                                                                   3/5/18
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/29507422
# STUDY                       A large electronic-health-record-based genome-...
# DISEASE/TRAIT                     High density lipoprotein cholesterol levels
# INITIAL SAMPLE SIZE         76,627 European ancestry individuals, 7,795 Hi...
# REPLICATION SAMPLE SIZE                                                   NaN
# REGION                                                                1p36.11
# CHR_ID                                                                      1
#  CHR_POS                                                          26,661,155
# REPORTED GENE(S)                                                           NR
# MAPPED_GENE                                           AL627082.1 - AL512408.1
# UPSTREAM_GENE_ID                                              ENSG00000235069
# DOWNSTREAM_GENE_ID                                            ENSG00000260063
# SNP_GENE_IDS                                                              NaN
# UPSTREAM_GENE_DISTANCE                                                  13474
# DOWNSTREAM_GENE_DISTANCE                                                30977
# STRONGEST SNP-RISK ALLELE                                       rs193084249-A
# SNPS                                                              rs193084249
# MERGED                                                                      0
# SNP_ID_CURRENT                                                    1.93084e+08
# CONTEXT                                                    intergenic_variant
# INTERGENIC                                                                  1
# RISK ALLELE FREQUENCY                                                    0.98
# P-VALUE                                                                 2e-14
# PVALUE_MLOG                                                            13.699
# P-VALUE (TEXT)                                                           (EA)
# OR or BETA                                                              0.113
# 95% CI (TEXT)                                                   unit increase
# PLATFORM [SNPS PASSING QC]            Affymetrix [at least 7091467] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST007140
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          2     \
# DATE ADDED TO CATALOG                                                 2/14/19
# PUBMEDID                                                             29507422
# FIRST AUTHOR                                                      Hoffmann TJ
# DATE                                                                   3/5/18
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/29507422
# STUDY                       A large electronic-health-record-based genome-...
# DISEASE/TRAIT                     High density lipoprotein cholesterol levels
# INITIAL SAMPLE SIZE         76,627 European ancestry individuals, 7,795 Hi...
# REPLICATION SAMPLE SIZE                                                   NaN
# REGION                                                                1p36.11
# CHR_ID                                                                      1
#  CHR_POS                                                          26,661,155
# REPORTED GENE(S)                                                           NR
# MAPPED_GENE                                           AL627082.1 - AL512408.1
# UPSTREAM_GENE_ID                                              ENSG00000235069
# DOWNSTREAM_GENE_ID                                            ENSG00000260063
# SNP_GENE_IDS                                                              NaN
# UPSTREAM_GENE_DISTANCE                                                  13474
# DOWNSTREAM_GENE_DISTANCE                                                30977
# STRONGEST SNP-RISK ALLELE                                       rs193084249-A
# SNPS                                                              rs193084249
# MERGED                                                                      0
# SNP_ID_CURRENT                                                    1.93084e+08
# CONTEXT                                                    intergenic_variant
# INTERGENIC                                                                  1
# RISK ALLELE FREQUENCY                                                      NR
# P-VALUE                                                                 2e-14
# PVALUE_MLOG                                                            13.699
# P-VALUE (TEXT)                                                            NaN
# OR or BETA                                                              0.114
# 95% CI (TEXT)                                                   unit increase
# PLATFORM [SNPS PASSING QC]            Affymetrix [at least 7091467] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST007140
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          3     \
# DATE ADDED TO CATALOG                                                 5/12/14
# PUBMEDID                                                             24097068
# FIRST AUTHOR                                                        Willer CJ
# DATE                                                                  10/6/13
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/24097068
# STUDY                       Discovery and refinement of loci associated wi...
# DISEASE/TRAIT                                                 HDL cholesterol
# INITIAL SAMPLE SIZE                      94,595 European ancestry individuals
# REPLICATION SAMPLE SIZE                  93,982 European ancestry individuals
# REGION                                                                1p36.11
# CHR_ID                                                                      1
#  CHR_POS                                                          26,811,902
# REPORTED GENE(S)                                                  PIGV, NR0B2
# MAPPED_GENE                                                  PIGV - RN7SL165P
# UPSTREAM_GENE_ID                                              ENSG00000060642
# DOWNSTREAM_GENE_ID                                            ENSG00000241188
# SNP_GENE_IDS                                                              NaN
# UPSTREAM_GENE_DISTANCE                                                  13504
# DOWNSTREAM_GENE_DISTANCE                                                 2920
# STRONGEST SNP-RISK ALLELE                                        rs12748152-T
# SNPS                                                               rs12748152
# MERGED                                                                      0
# SNP_ID_CURRENT                                                    1.27482e+07
# CONTEXT                                                    intergenic_variant
# INTERGENIC                                                                  1
# RISK ALLELE FREQUENCY                                                    0.09
# P-VALUE                                                                 1e-15
# PVALUE_MLOG                                                                15
# P-VALUE (TEXT)                                                            NaN
# OR or BETA                                                              0.051
# 95% CI (TEXT)                                              [NR] unit decrease
# PLATFORM [SNPS PASSING QC]                                  NR [NR] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST002223
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          4     \
# DATE ADDED TO CATALOG                                                 6/26/17
# PUBMEDID                                                             28334899
# FIRST AUTHOR                                                     Spracklen CN
# DATE                                                                  2/21/17
# JOURNAL                                                         Hum Mol Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/28334899
# STUDY                       Association analyses of East Asian individuals...
# DISEASE/TRAIT                                          HDL cholesterol levels
# INITIAL SAMPLE SIZE         34,930 East Asian ancestry individuals, 187,16...
# REPLICATION SAMPLE SIZE                    8,741 Chinese ancestry individuals
# REGION                                                                1p36.11
# CHR_ID                                                                      1
#  CHR_POS                                                          26,811,902
# REPORTED GENE(S)                                                  PIGV, NROB2
# MAPPED_GENE                                                  PIGV - RN7SL165P
# UPSTREAM_GENE_ID                                              ENSG00000060642
# DOWNSTREAM_GENE_ID                                            ENSG00000241188
# SNP_GENE_IDS                                                              NaN
# UPSTREAM_GENE_DISTANCE                                                  13504
# DOWNSTREAM_GENE_DISTANCE                                                 2920
# STRONGEST SNP-RISK ALLELE                                        rs12748152-T
# SNPS                                                               rs12748152
# MERGED                                                                      0
# SNP_ID_CURRENT                                                    1.27482e+07
# CONTEXT                                                    intergenic_variant
# INTERGENIC                                                                  1
# RISK ALLELE FREQUENCY                                                  0.0712
# P-VALUE                                                                 9e-16
# PVALUE_MLOG                                                           15.0458
# P-VALUE (TEXT)                                         (Trans-ethnic initial)
# OR or BETA                                                             0.0506
# 95% CI (TEXT)                    [0.038-0.063] unit decrease (EA Beta values)
# PLATFORM [SNPS PASSING QC]         Affymetrix, Illumina [~ 1900000] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST004232
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          5     \
# DATE ADDED TO CATALOG                                                 2/14/19
# PUBMEDID                                                             29507422
# FIRST AUTHOR                                                      Hoffmann TJ
# DATE                                                                   3/5/18
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/29507422
# STUDY                       A large electronic-health-record-based genome-...
# DISEASE/TRAIT                     High density lipoprotein cholesterol levels
# INITIAL SAMPLE SIZE         76,627 European ancestry individuals, 7,795 Hi...
# REPLICATION SAMPLE SIZE                                                   NaN
# REGION                                                                1p36.11
# CHR_ID                                                                      1
#  CHR_POS                                                          26,811,902
# REPORTED GENE(S)                                                           NR
# MAPPED_GENE                                                  PIGV - RN7SL165P
# UPSTREAM_GENE_ID                                              ENSG00000060642
# DOWNSTREAM_GENE_ID                                            ENSG00000241188
# SNP_GENE_IDS                                                              NaN
# UPSTREAM_GENE_DISTANCE                                                  13504
# DOWNSTREAM_GENE_DISTANCE                                                 2920
# STRONGEST SNP-RISK ALLELE                                        rs12748152-C
# SNPS                                                               rs12748152
# MERGED                                                                      0
# SNP_ID_CURRENT                                                    1.27482e+07
# CONTEXT                                                    intergenic_variant
# INTERGENIC                                                                  1
# RISK ALLELE FREQUENCY                                                   0.925
# P-VALUE                                                                 5e-13
# PVALUE_MLOG                                                            12.301
# P-VALUE (TEXT)                                                           (EA)
# OR or BETA                                                              0.051
# 95% CI (TEXT)                                                   unit increase
# PLATFORM [SNPS PASSING QC]            Affymetrix [at least 7091467] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST007140
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          6     \
# DATE ADDED TO CATALOG                                                 2/14/19
# PUBMEDID                                                             29507422
# FIRST AUTHOR                                                      Hoffmann TJ
# DATE                                                                   3/5/18
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/29507422
# STUDY                       A large electronic-health-record-based genome-...
# DISEASE/TRAIT                     High density lipoprotein cholesterol levels
# INITIAL SAMPLE SIZE         76,627 European ancestry individuals, 7,795 Hi...
# REPLICATION SAMPLE SIZE                                                   NaN
# REGION                                                                1p36.11
# CHR_ID                                                                      1
#  CHR_POS                                                          26,811,902
# REPORTED GENE(S)                                                           NR
# MAPPED_GENE                                                  PIGV - RN7SL165P
# UPSTREAM_GENE_ID                                              ENSG00000060642
# DOWNSTREAM_GENE_ID                                            ENSG00000241188
# SNP_GENE_IDS                                                              NaN
# UPSTREAM_GENE_DISTANCE                                                  13504
# DOWNSTREAM_GENE_DISTANCE                                                 2920
# STRONGEST SNP-RISK ALLELE                                        rs12748152-C
# SNPS                                                               rs12748152
# MERGED                                                                      0
# SNP_ID_CURRENT                                                    1.27482e+07
# CONTEXT                                                    intergenic_variant
# INTERGENIC                                                                  1
# RISK ALLELE FREQUENCY                                                      NR
# P-VALUE                                                                 3e-14
# PVALUE_MLOG                                                           13.5229
# P-VALUE (TEXT)                                                            NaN
# OR or BETA                                                              0.052
# 95% CI (TEXT)                                                   unit increase
# PLATFORM [SNPS PASSING QC]            Affymetrix [at least 7091467] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST007140
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          7     \
# DATE ADDED TO CATALOG                                                 2/14/19
# PUBMEDID                                                             29507422
# FIRST AUTHOR                                                      Hoffmann TJ
# DATE                                                                   3/5/18
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/29507422
# STUDY                       A large electronic-health-record-based genome-...
# DISEASE/TRAIT                     High density lipoprotein cholesterol levels
# INITIAL SAMPLE SIZE         76,627 European ancestry individuals, 7,795 Hi...
# REPLICATION SAMPLE SIZE                                                   NaN
# REGION                                                                1p36.11
# CHR_ID                                                                      1
#  CHR_POS                                                          26,958,422
# REPORTED GENE(S)                                                           NR
# MAPPED_GENE                                                              KDF1
# UPSTREAM_GENE_ID                                                          NaN
# DOWNSTREAM_GENE_ID                                                        NaN
# SNP_GENE_IDS                                                  ENSG00000175707
# UPSTREAM_GENE_DISTANCE                                                    NaN
# DOWNSTREAM_GENE_DISTANCE                                                  NaN
# STRONGEST SNP-RISK ALLELE                                        rs79598313-C
# SNPS                                                               rs79598313
# MERGED                                                                      0
# SNP_ID_CURRENT                                                    7.95983e+07
# CONTEXT                                                        intron_variant
# INTERGENIC                                                                  0
# RISK ALLELE FREQUENCY                                                   0.979
# P-VALUE                                                                 4e-14
# PVALUE_MLOG                                                           13.3979
# P-VALUE (TEXT)                                                           (EA)
# OR or BETA                                                              0.099
# 95% CI (TEXT)                                                   unit increase
# PLATFORM [SNPS PASSING QC]            Affymetrix [at least 7091467] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST007140
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          8     \
# DATE ADDED TO CATALOG                                                 2/14/19
# PUBMEDID                                                             29507422
# FIRST AUTHOR                                                      Hoffmann TJ
# DATE                                                                   3/5/18
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/29507422
# STUDY                       A large electronic-health-record-based genome-...
# DISEASE/TRAIT                     High density lipoprotein cholesterol levels
# INITIAL SAMPLE SIZE         76,627 European ancestry individuals, 7,795 Hi...
# REPLICATION SAMPLE SIZE                                                   NaN
# REGION                                                                1p36.11
# CHR_ID                                                                      1
#  CHR_POS                                                          26,958,422
# REPORTED GENE(S)                                                           NR
# MAPPED_GENE                                                              KDF1
# UPSTREAM_GENE_ID                                                          NaN
# DOWNSTREAM_GENE_ID                                                        NaN
# SNP_GENE_IDS                                                  ENSG00000175707
# UPSTREAM_GENE_DISTANCE                                                    NaN
# DOWNSTREAM_GENE_DISTANCE                                                  NaN
# STRONGEST SNP-RISK ALLELE                                        rs79598313-C
# SNPS                                                               rs79598313
# MERGED                                                                      0
# SNP_ID_CURRENT                                                    7.95983e+07
# CONTEXT                                                        intron_variant
# INTERGENIC                                                                  0
# RISK ALLELE FREQUENCY                                                      NR
# P-VALUE                                                                 1e-14
# PVALUE_MLOG                                                                14
# P-VALUE (TEXT)                                                            NaN
# OR or BETA                                                              0.098
# 95% CI (TEXT)                                                   unit increase
# PLATFORM [SNPS PASSING QC]            Affymetrix [at least 7091467] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST007140
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          9     \
# DATE ADDED TO CATALOG                                                11/26/18
# PUBMEDID                                                             30275531
# FIRST AUTHOR                                                         Klarin D
# DATE                                                                  10/1/18
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/30275531
# STUDY                       Genetics of blood lipids among ~300,000 multi-...
# DISEASE/TRAIT                                                 HDL cholesterol
# INITIAL SAMPLE SIZE         215,551 European ancestry individuals, 57,332 ...
# REPLICATION SAMPLE SIZE                             Up to 319,677 individuals
# REGION                                                                1p36.11
# CHR_ID                                                                      1
#  CHR_POS                                                          26,958,422
# REPORTED GENE(S)                                                     C1orf172
# MAPPED_GENE                                                              KDF1
# UPSTREAM_GENE_ID                                                          NaN
# DOWNSTREAM_GENE_ID                                                        NaN
# SNP_GENE_IDS                                                  ENSG00000175707
# UPSTREAM_GENE_DISTANCE                                                    NaN
# DOWNSTREAM_GENE_DISTANCE                                                  NaN
# STRONGEST SNP-RISK ALLELE                                        rs79598313-T
# SNPS                                                               rs79598313
# MERGED                                                                      0
# SNP_ID_CURRENT                                                    7.95983e+07
# CONTEXT                                                        intron_variant
# INTERGENIC                                                                  0
# RISK ALLELE FREQUENCY                                                  0.0216
# P-VALUE                                                                 3e-19
# PVALUE_MLOG                                                           18.5229
# P-VALUE (TEXT)                                                            NaN
# OR or BETA                                                             0.0898
# 95% CI (TEXT)                                   [0.07-0.109] mg dl−1 decrease
# PLATFORM [SNPS PASSING QC]              Affymetrix [up to 31400000] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST006611
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                             ...  \
# DATE ADDED TO CATALOG       ...
# PUBMEDID                    ...
# FIRST AUTHOR                ...
# DATE                        ...
# JOURNAL                     ...
# LINK                        ...
# STUDY                       ...
# DISEASE/TRAIT               ...
# INITIAL SAMPLE SIZE         ...
# REPLICATION SAMPLE SIZE     ...
# REGION                      ...
# CHR_ID                      ...
#  CHR_POS                    ...
# REPORTED GENE(S)            ...
# MAPPED_GENE                 ...
# UPSTREAM_GENE_ID            ...
# DOWNSTREAM_GENE_ID          ...
# SNP_GENE_IDS                ...
# UPSTREAM_GENE_DISTANCE      ...
# DOWNSTREAM_GENE_DISTANCE    ...
# STRONGEST SNP-RISK ALLELE   ...
# SNPS                        ...
# MERGED                      ...
# SNP_ID_CURRENT              ...
# CONTEXT                     ...
# INTERGENIC                  ...
# RISK ALLELE FREQUENCY       ...
# P-VALUE                     ...
# PVALUE_MLOG                 ...
# P-VALUE (TEXT)              ...
# OR or BETA                  ...
# 95% CI (TEXT)               ...
# PLATFORM [SNPS PASSING QC]  ...
# CNV                         ...
# MAPPED_TRAIT                ...
# MAPPED_TRAIT_URI            ...
# STUDY ACCESSION             ...
# GENOTYPING TECHNOLOGY       ...
#
#                                                                          1290  \
# DATE ADDED TO CATALOG                                                 7/28/18
# PUBMEDID                                                             29403010
# FIRST AUTHOR                                                          Kanai M
# DATE                                                                   2/5/18
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/29403010
# STUDY                       Genetic analysis of quantitative traits in the...
# DISEASE/TRAIT                     High density lipoprotein cholesterol levels
# INITIAL SAMPLE SIZE                      70,657 Japanese ancestry individuals
# REPLICATION SAMPLE SIZE                                                   NaN
# REGION                                                               22q11.21
# CHR_ID                                                                     22
#  CHR_POS                                                          21,622,758
# REPORTED GENE(S)                                                       UBE2L3
# MAPPED_GENE                                                            UBE2L3
# UPSTREAM_GENE_ID                                                          NaN
# DOWNSTREAM_GENE_ID                                                        NaN
# SNP_GENE_IDS                                                  ENSG00000185651
# UPSTREAM_GENE_DISTANCE                                                    NaN
# DOWNSTREAM_GENE_DISTANCE                                                  NaN
# STRONGEST SNP-RISK ALLELE                                            rs7445-?
# SNPS                                                                   rs7445
# MERGED                                                                      0
# SNP_ID_CURRENT                                                           7445
# CONTEXT                                                   3_prime_UTR_variant
# INTERGENIC                                                                  0
# RISK ALLELE FREQUENCY                                                      NR
# P-VALUE                                                                 1e-14
# PVALUE_MLOG                                                                14
# P-VALUE (TEXT)                                                            NaN
# OR or BETA                                                            0.04087
# 95% CI (TEXT)                                [0.03-0.051] unit decrease novel
# PLATFORM [SNPS PASSING QC]                       Illumina [6108953] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST006005
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          1291  \
# DATE ADDED TO CATALOG                                                 2/14/19
# PUBMEDID                                                             29507422
# FIRST AUTHOR                                                      Hoffmann TJ
# DATE                                                                   3/5/18
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/29507422
# STUDY                       A large electronic-health-record-based genome-...
# DISEASE/TRAIT                     High density lipoprotein cholesterol levels
# INITIAL SAMPLE SIZE         76,627 European ancestry individuals, 7,795 Hi...
# REPLICATION SAMPLE SIZE                                                   NaN
# REGION                                                               22q11.21
# CHR_ID                                                                     22
#  CHR_POS                                                          21,627,765
# REPORTED GENE(S)                                                           NR
# MAPPED_GENE                                                     UBE2L3 - YDJC
# UPSTREAM_GENE_ID                                              ENSG00000185651
# DOWNSTREAM_GENE_ID                                            ENSG00000161179
# SNP_GENE_IDS                                                              NaN
# UPSTREAM_GENE_DISTANCE                                                   3731
# DOWNSTREAM_GENE_DISTANCE                                                  324
# STRONGEST SNP-RISK ALLELE                                         rs1811069-T
# SNPS                                                                rs1811069
# MERGED                                                                      0
# SNP_ID_CURRENT                                                    1.81107e+06
# CONTEXT                                                    intergenic_variant
# INTERGENIC                                                                  1
# RISK ALLELE FREQUENCY                                                   0.801
# P-VALUE                                                                 4e-09
# PVALUE_MLOG                                                           8.39794
# P-VALUE (TEXT)                                                           (EA)
# OR or BETA                                                              0.028
# 95% CI (TEXT)                                                   unit increase
# PLATFORM [SNPS PASSING QC]            Affymetrix [at least 7091467] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST007140
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          1292  \
# DATE ADDED TO CATALOG                                                 2/14/19
# PUBMEDID                                                             29507422
# FIRST AUTHOR                                                      Hoffmann TJ
# DATE                                                                   3/5/18
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/29507422
# STUDY                       A large electronic-health-record-based genome-...
# DISEASE/TRAIT                     High density lipoprotein cholesterol levels
# INITIAL SAMPLE SIZE         76,627 European ancestry individuals, 7,795 Hi...
# REPLICATION SAMPLE SIZE                                                   NaN
# REGION                                                               22q11.21
# CHR_ID                                                                     22
#  CHR_POS                                                          21,627,765
# REPORTED GENE(S)                                                           NR
# MAPPED_GENE                                                     UBE2L3 - YDJC
# UPSTREAM_GENE_ID                                              ENSG00000185651
# DOWNSTREAM_GENE_ID                                            ENSG00000161179
# SNP_GENE_IDS                                                              NaN
# UPSTREAM_GENE_DISTANCE                                                   3731
# DOWNSTREAM_GENE_DISTANCE                                                  324
# STRONGEST SNP-RISK ALLELE                                         rs1811069-T
# SNPS                                                                rs1811069
# MERGED                                                                      0
# SNP_ID_CURRENT                                                    1.81107e+06
# CONTEXT                                                    intergenic_variant
# INTERGENIC                                                                  1
# RISK ALLELE FREQUENCY                                                      NR
# P-VALUE                                                                 1e-13
# PVALUE_MLOG                                                                13
# P-VALUE (TEXT)                                                            NaN
# OR or BETA                                                              0.031
# 95% CI (TEXT)                                                   unit increase
# PLATFORM [SNPS PASSING QC]            Affymetrix [at least 7091467] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST007140
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          1293  \
# DATE ADDED TO CATALOG                                                11/26/18
# PUBMEDID                                                             30275531
# FIRST AUTHOR                                                         Klarin D
# DATE                                                                  10/1/18
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/30275531
# STUDY                       Genetics of blood lipids among ~300,000 multi-...
# DISEASE/TRAIT                                                 HDL cholesterol
# INITIAL SAMPLE SIZE         215,551 European ancestry individuals, 57,332 ...
# REPLICATION SAMPLE SIZE                             Up to 319,677 individuals
# REGION                                                                22q12.1
# CHR_ID                                                                     22
#  CHR_POS                                                          29,004,527
# REPORTED GENE(S)                                                        ZNRF3
# MAPPED_GENE                                                  ZNRF3, ZNRF3-IT1
# UPSTREAM_GENE_ID                                                          NaN
# DOWNSTREAM_GENE_ID                                                        NaN
# SNP_GENE_IDS                                 ENSG00000183579, ENSG00000235786
# UPSTREAM_GENE_DISTANCE                                                    NaN
# DOWNSTREAM_GENE_DISTANCE                                                  NaN
# STRONGEST SNP-RISK ALLELE                                         rs8142788-A
# SNPS                                                                rs8142788
# MERGED                                                                      0
# SNP_ID_CURRENT                                                    8.14279e+06
# CONTEXT                                                        intron_variant
# INTERGENIC                                                                  0
# RISK ALLELE FREQUENCY                                                  0.1559
# P-VALUE                                                                 1e-08
# PVALUE_MLOG                                                                 8
# P-VALUE (TEXT)                                                            NaN
# OR or BETA                                                              0.023
# 95% CI (TEXT)                                  [0.015-0.031] mg dl−1 decrease
# PLATFORM [SNPS PASSING QC]              Affymetrix [up to 31400000] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST006611
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          1294  \
# DATE ADDED TO CATALOG                                                 2/14/19
# PUBMEDID                                                             29507422
# FIRST AUTHOR                                                      Hoffmann TJ
# DATE                                                                   3/5/18
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/29507422
# STUDY                       A large electronic-health-record-based genome-...
# DISEASE/TRAIT                     High density lipoprotein cholesterol levels
# INITIAL SAMPLE SIZE         76,627 European ancestry individuals, 7,795 Hi...
# REPLICATION SAMPLE SIZE                                                   NaN
# REGION                                                                22q13.1
# CHR_ID                                                                     22
#  CHR_POS                                                          38,179,492
# REPORTED GENE(S)                                                           NR
# MAPPED_GENE                                                            PLA2G6
# UPSTREAM_GENE_ID                                                          NaN
# DOWNSTREAM_GENE_ID                                                        NaN
# SNP_GENE_IDS                                                  ENSG00000184381
# UPSTREAM_GENE_DISTANCE                                                    NaN
# DOWNSTREAM_GENE_DISTANCE                                                  NaN
# STRONGEST SNP-RISK ALLELE                                         rs133027-CT
# SNPS                                                                 rs133027
# MERGED                                                                      0
# SNP_ID_CURRENT                                                         133027
# CONTEXT                                                        intron_variant
# INTERGENIC                                                                  0
# RISK ALLELE FREQUENCY                                                    0.56
# P-VALUE                                                                 9e-11
# ...
# STUDY ACCESSION                                                    GCST007140
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          1295  \
# DATE ADDED TO CATALOG                                                 2/14/19
# PUBMEDID                                                             29507422
# FIRST AUTHOR                                                      Hoffmann TJ
# DATE                                                                   3/5/18
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/29507422
# STUDY                       A large electronic-health-record-based genome-...
# DISEASE/TRAIT                     High density lipoprotein cholesterol levels
# INITIAL SAMPLE SIZE         76,627 European ancestry individuals, 7,795 Hi...
# REPLICATION SAMPLE SIZE                                                   NaN
# REGION                                                                22q13.1
# CHR_ID                                                                     22
#  CHR_POS                                                          38,179,492
# REPORTED GENE(S)                                                           NR
# MAPPED_GENE                                                            PLA2G6
# UPSTREAM_GENE_ID                                                          NaN
# DOWNSTREAM_GENE_ID                                                        NaN
# SNP_GENE_IDS                                                  ENSG00000184381
# UPSTREAM_GENE_DISTANCE                                                    NaN
# DOWNSTREAM_GENE_DISTANCE                                                  NaN
# STRONGEST SNP-RISK ALLELE                                         rs133027-CT
# SNPS                                                                 rs133027
# MERGED                                                                      0
# SNP_ID_CURRENT                                                         133027
# CONTEXT                                                        intron_variant
# INTERGENIC                                                                  0
# RISK ALLELE FREQUENCY                                                      NR
# P-VALUE                                                                 2e-12
# PVALUE_MLOG                                                            11.699
# P-VALUE (TEXT)                                                            NaN
# OR or BETA                                                              0.025
# 95% CI (TEXT)                                                   unit decrease
# PLATFORM [SNPS PASSING QC]            Affymetrix [at least 7091467] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST007140
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          1296  \
# DATE ADDED TO CATALOG                                                11/26/18
# PUBMEDID                                                             30275531
# FIRST AUTHOR                                                         Klarin D
# DATE                                                                  10/1/18
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/30275531
# STUDY                       Genetics of blood lipids among ~300,000 multi-...
# DISEASE/TRAIT                                                 HDL cholesterol
# INITIAL SAMPLE SIZE         215,551 European ancestry individuals, 57,332 ...
# REPLICATION SAMPLE SIZE                             Up to 319,677 individuals
# REGION                                                                22q13.1
# CHR_ID                                                                     22
#  CHR_POS                                                          38,198,661
# REPORTED GENE(S)                                                         MAFF
# MAPPED_GENE                                                            PLA2G6
# UPSTREAM_GENE_ID                                                          NaN
# DOWNSTREAM_GENE_ID                                                        NaN
# SNP_GENE_IDS                                                  ENSG00000184381
# UPSTREAM_GENE_DISTANCE                                                    NaN
# DOWNSTREAM_GENE_DISTANCE                                                  NaN
# STRONGEST SNP-RISK ALLELE                                         rs2899297-A
# SNPS                                                                rs2899297
# MERGED                                                                      0
# SNP_ID_CURRENT                                                     2.8993e+06
# CONTEXT                                                        intron_variant
# INTERGENIC                                                                  0
# RISK ALLELE FREQUENCY                                                  0.5479
# P-VALUE                                                                 1e-16
# PVALUE_MLOG                                                                16
# P-VALUE (TEXT)                                                            NaN
# OR or BETA                                                             0.0225
# 95% CI (TEXT)                                  [0.017-0.028] mg dl−1 decrease
# PLATFORM [SNPS PASSING QC]              Affymetrix [up to 31400000] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST006611
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          1297  \
# DATE ADDED TO CATALOG                                                11/26/18
# PUBMEDID                                                             30275531
# FIRST AUTHOR                                                         Klarin D
# DATE                                                                  10/1/18
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/30275531
# STUDY                       Genetics of blood lipids among ~300,000 multi-...
# DISEASE/TRAIT                                                 HDL cholesterol
# INITIAL SAMPLE SIZE         215,551 European ancestry individuals, 57,332 ...
# REPLICATION SAMPLE SIZE                             Up to 319,677 individuals
# REGION                                                               22q13.31
# CHR_ID                                                                     22
#  CHR_POS                                                          43,945,024
# REPORTED GENE(S)                                                       PNPLA3
# MAPPED_GENE                                                            PNPLA3
# UPSTREAM_GENE_ID                                                          NaN
# DOWNSTREAM_GENE_ID                                                        NaN
# SNP_GENE_IDS                                                  ENSG00000100344
# UPSTREAM_GENE_DISTANCE                                                    NaN
# DOWNSTREAM_GENE_DISTANCE                                                  NaN
# STRONGEST SNP-RISK ALLELE                                         rs2294915-T
# SNPS                                                                rs2294915
# MERGED                                                                      0
# SNP_ID_CURRENT                                                    2.29492e+06
# CONTEXT                                                        intron_variant
# INTERGENIC                                                                  0
# RISK ALLELE FREQUENCY                                                   0.246
# P-VALUE                                                                 3e-08
# PVALUE_MLOG                                                           7.52288
# P-VALUE (TEXT)                                                            NaN
# OR or BETA                                                             0.0177
# 95% CI (TEXT)                                  [0.011-0.024] mg dl−1 decrease
# PLATFORM [SNPS PASSING QC]              Affymetrix [up to 31400000] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST006611
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          1298  \
# DATE ADDED TO CATALOG                                                 2/14/19
# PUBMEDID                                                             29507422
# FIRST AUTHOR                                                      Hoffmann TJ
# DATE                                                                   3/5/18
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/29507422
# STUDY                       A large electronic-health-record-based genome-...
# DISEASE/TRAIT                     High density lipoprotein cholesterol levels
# INITIAL SAMPLE SIZE         76,627 European ancestry individuals, 7,795 Hi...
# REPLICATION SAMPLE SIZE                                                   NaN
# REGION                                                                 Xp22.2
# CHR_ID                                                                      X
#  CHR_POS                                                          14,841,981
# REPORTED GENE(S)                                                           NR
# MAPPED_GENE                                                             FANCB
# UPSTREAM_GENE_ID                                                          NaN
# DOWNSTREAM_GENE_ID                                                        NaN
# SNP_GENE_IDS                                                  ENSG00000181544
# UPSTREAM_GENE_DISTANCE                                                    NaN
# DOWNSTREAM_GENE_DISTANCE                                                  NaN
# STRONGEST SNP-RISK ALLELE                                       rs138331350-G
# SNPS                                                              rs138331350
# MERGED                                                                      0
# SNP_ID_CURRENT                                                    1.38331e+08
# CONTEXT                                                        intron_variant
# INTERGENIC                                                                  0
# RISK ALLELE FREQUENCY                                                   0.942
# P-VALUE                                                                 3e-11
# PVALUE_MLOG                                                           10.5229
# P-VALUE (TEXT)                                                           (EA)
# OR or BETA                                                              0.048
# 95% CI (TEXT)                                                   unit decrease
# PLATFORM [SNPS PASSING QC]            Affymetrix [at least 7091467] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST007140
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
#                                                                          1299
# DATE ADDED TO CATALOG                                                 2/14/19
# PUBMEDID                                                             29507422
# FIRST AUTHOR                                                      Hoffmann TJ
# DATE                                                                   3/5/18
# JOURNAL                                                             Nat Genet
# LINK                                     www.ncbi.nlm.nih.gov/pubmed/29507422
# STUDY                       A large electronic-health-record-based genome-...
# DISEASE/TRAIT                     High density lipoprotein cholesterol levels
# INITIAL SAMPLE SIZE         76,627 European ancestry individuals, 7,795 Hi...
# REPLICATION SAMPLE SIZE                                                   NaN
# REGION                                                                 Xp22.2
# CHR_ID                                                                      X
#  CHR_POS                                                          14,841,981
# REPORTED GENE(S)                                                           NR
# MAPPED_GENE                                                             FANCB
# UPSTREAM_GENE_ID                                                          NaN
# DOWNSTREAM_GENE_ID                                                        NaN
# SNP_GENE_IDS                                                  ENSG00000181544
# UPSTREAM_GENE_DISTANCE                                                    NaN
# DOWNSTREAM_GENE_DISTANCE                                                  NaN
# STRONGEST SNP-RISK ALLELE                                       rs138331350-G
# SNPS                                                              rs138331350
# MERGED                                                                      0
# SNP_ID_CURRENT                                                    1.38331e+08
# CONTEXT                                                        intron_variant
# INTERGENIC                                                                  0
# RISK ALLELE FREQUENCY                                                      NR
# P-VALUE                                                                 1e-12
# PVALUE_MLOG                                                                12
# P-VALUE (TEXT)                                                            NaN
# OR or BETA                                                              0.049
# 95% CI (TEXT)                                                   unit decrease
# PLATFORM [SNPS PASSING QC]            Affymetrix [at least 7091467] (imputed)
# CNV                                                                         N
# MAPPED_TRAIT                 high density lipoprotein cholesterol measurement
# MAPPED_TRAIT_URI                         http://www.ebi.ac.uk/efo/EFO_0004612
# STUDY ACCESSION                                                    GCST007140
# GENOTYPING TECHNOLOGY                            Genome-wide genotyping array
#
# [38 rows x 1300 columns]
